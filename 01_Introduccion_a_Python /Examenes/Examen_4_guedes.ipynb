# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoGuedesDP/Programacion_101/blob/main/01_Introduccion_a_Python%20/Examenes/Examen_4_guedes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pregunta N° 01
#
# Carga diabetes.csv en un DataFrame df_diabetes.
# Muestra las 5 primeras filas.
# Imprime el número total de filas, columnas y el tipo de cada columna.
# Convierte la columna Outcome a tipo categórico y verifica el cambio imprimiendo la información del DataFrame (df_diabetes.info()).

# %%
import pandas as pd
df_diabetes = pd.read_csv('diabetes.csv')

print(df_diabetes.head())
print("Número de filas y columnas:", df_diabetes.shape)
print(df_diabetes.info())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# Número de filas y columnas: (768, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None

# %%
#Convertimos la columna Outcome a tipo categorico
df_diabetes['Outcome'] = df_diabetes['Outcome'].astype('category')
df_diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    category
# dtypes: category(1), float64(2), int64(6)
# memory usage: 49.0 KB

# %% [markdown]
# Pregunta N° 02:
#
# Crea un DataFrame df_filtrado con todas las filas de df_diabetes donde Glucose > 120.
# Agrega a df_filtrado una columna BMI_Category que clasifique el BMI así:
# "Bajo" si BMI < 18.5
# "Normal" si 18.5 ≤ BMI < 25
# "Sobrepeso" si 25 ≤ BMI < 30
# "Obeso" si BMI ≥ 30
# Muestra las primeras 5 filas de df_filtrado con la nueva columna incluida.

# %%
df_filtrado =df_diabetes[df_diabetes['Glucose']>120]
#Creamos una funcion para categorizar el BMI
def categoria_bmi(bmi):
    if bmi < 18.5:
        return 'Bajo'
    elif 18.5 <= bmi < 25:
        return 'Normal'
    elif 25 <= bmi < 30:
        return 'Sobrepeso'
    else:
        return 'Obeso'

df_filtrado["BMI_Category"] = df_filtrado["BMI"].apply(categoria_bmi)
print(df_filtrado.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 2            8      183             64              0        0  23.3
# 4            0      137             40             35      168  43.1
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age Outcome BMI_Category
# 0                     0.627   50       1        Obeso
# 2                     0.672   32       1       Normal
# 4                     2.288   33       1        Obeso
# 8                     0.158   53       1        Obeso
# 9                     0.232   54       1         Bajo
# <ipython-input-5-8cae860b9b39>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado["BMI_Category"] = df_filtrado["BMI"].apply(categoria_bmi)

# %% [markdown]
# Pregunta N° 03:
#
# Carga age_groups.csv en un DataFrame df_age_groups.
# Haz un merge de df_diabetes con df_age_groups por la columna Age. El resultado se llamará df_combinado. Debe ser un left merge para mantener todas las filas de df_diabetes.
# Muestra las 5 primeras filas de df_combinado para verificar que la columna AgeGroup se haya agregado correctamente.

# %%
df_age_groups = pd.read_csv('age_groups.csv')
df_combinado = pd.merge(df_diabetes, df_age_groups, on = 'Age', how = 'left')

print("Primeras 5 filas de df_combinado:")
print(df_combinado.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age Outcome AgeGroup
# 0                     0.627   50       1   Adulto
# 1                     0.351   31       0   Adulto
# 2                     0.672   32       1   Adulto
# 3                     0.167   21       0    Joven
# 4                     2.288   33       1   Adulto

# %% [markdown]
# Pregunta N° 04:
#
# Agrupa df_combinado por AgeGroup.
# Calcula el promedio de Glucose y el promedio de BMI para cada grupo de edad.
# Ordena el resultado por el promedio de Glucose de mayor a menor.
# Muestra el DataFrame resultante.

# %%
agrupado = df_combinado.groupby(['AgeGroup']).agg({"Glucose": 'mean','BMI': 'mean'})
agrupado_ordenado = agrupado.sort_values('Glucose', ascending = False)
print("Promedios por grupo de edad:")
print(agrupado_ordenado)
# Out:
# Promedios por grupo de edad:
#                  Glucose        BMI
# AgeGroup
# Adulto_Mayor  139.679012  30.211111
# Adulto        125.637037  33.562593
# Joven         114.175060  31.322062

# %% [markdown]
# Pregunta N° 05:
#
# A partir de df_combinado, filtra las filas donde AgeGroup = "Adulto" y Outcome = 1 (casos positivos de diabetes en adultos).
# De este subconjunto, selecciona los 5 registros con el mayor valor de BMI.
# Muestra únicamente las columnas Age, Glucose, BMI, DiabetesPedigreeFunction, ordenadas por BMI de mayor a menor.

# %%
df_adultos_diabetes = df_combinado[(df_combinado['AgeGroup'] == 'Adulto') & (df_combinado['Outcome'] == 1)]
top_5_bmi = (df_adultos_diabetes.nlargest(5, 'BMI')[['Age', 'Glucose', 'BMI', 'DiabetesPedigreeFunction']].sort_values('BMI', ascending=False))

print("Top 5 BMI en adultos con diabetes:")
print(top_5_bmi)
top_5_bmi
# Out:
# Top 5 BMI en adultos con diabetes:
#      Age  Glucose   BMI  DiabetesPedigreeFunction
# 193   40      135  52.3                     0.578
# 155   36      152  50.0                     0.337
# 99    31      122  49.7                     0.325
# 84    37      137  48.8                     0.227
# 378   32      156  48.3                     0.238
#      Age  Glucose   BMI  DiabetesPedigreeFunction
# 193   40      135  52.3                     0.578
# 155   36      152  50.0                     0.337
# 99    31      122  49.7                     0.325
# 84    37      137  48.8                     0.227
# 378   32      156  48.3                     0.238

# %% [markdown]
# Pregunta N° 06:
#
# Usando df_combinado, crea una tabla pivote que tenga:
# Índice: AgeGroup
# Columnas: Outcome
# Valores: promedio de Glucose y BMI
# La pivot table debe mostrar el promedio de Glucose y BMI por combinación de AgeGroup y Outcome.
# De la tabla resultante, filtra y muestra únicamente las filas (AgeGroups) donde el promedio de BMI para cualquiera de los valores de Outcome sea mayor a 30.

# %%
pivot_table = pd.pivot_table(df_combinado, values=['Glucose', 'BMI'], index='AgeGroup', columns='Outcome', aggfunc='mean')

resultado_final = pivot_table[(pivot_table[('BMI', 0)] > 30) | (pivot_table[('BMI', 1)] > 30)]

print("Tabla pivote filtrada:")
print(resultado_final)
resultado_final
# Out:
# Tabla pivote filtrada:
#                     BMI                Glucose
# Outcome               0          1           0           1
# AgeGroup
# Adulto        31.923077  35.085000  111.830769  138.457143
# Adulto_Mayor  28.413953  32.244737  127.209302  153.789474
# Joven         29.909174  36.455556  106.978593  140.322222
# <ipython-input-12-e84f3ce21216>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_table = pd.pivot_table(df_combinado, values=['Glucose', 'BMI'], index='AgeGroup', columns='Outcome', aggfunc='mean')
#                     BMI                Glucose
# Outcome               0          1           0           1
# AgeGroup
# Adulto        31.923077  35.085000  111.830769  138.457143
# Adulto_Mayor  28.413953  32.244737  127.209302  153.789474
# Joven         29.909174  36.455556  106.978593  140.322222
